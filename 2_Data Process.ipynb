# %%
#Operating system
from pathlib import Path

#Data processing
import pandas as pd
import numpy as np

#Print output
from pprint import pprint

#Read/write csv files
import csv 

import nltk

#Lemmatisation
from nltk import WordNetLemmatizer

#Stopwords
from nltk.corpus import stopwords

#Word tokenize
from nltk.tokenize import word_tokenize

# %%
#Import data
speech_df = pd.read_csv(Path.cwd() / "raw_speeches_df.txt")
speech_df.head()
# Out:
#          date                       title  \
# 0  2010-02-01     2010_Budget_to_Congress
# 1  2016-09-11          911_After_15_Years
# 2  2009-09-11  911_Pentagon_Memorial_2009
# 3  2010-09-11  911_Pentagon_Memorial_2010
# 4  2011-03-18            Address_on_Libya
#
#                                              content
# 0   Good morning, everybody. This morning, I sent...
# 1   Good morning.  Scripture tells us, “Let not s...
# 2   Secretary Gates, Admiral Mullen and members o...
# 3   Secretary Gates, Admiral Mullen and members o...
# 4    Good afternoon, everybody.I want to take thi...

# %%
#Define the Stopwords
StopWords = stopwords.words("english")

#Modify the Stopwords and add some extra stopwords
StopWords.extend(['from','u','obama','president'])

# %%
#Function of text processing
def clean_text(text):
    
    #Tokenize
    tokens = word_tokenize(text)
    
    #Remove the punctuations
    tokens = [word for word in tokens if word.isalpha()]
    
    #Lower the tokens
    tokens = [word.lower() for word in tokens]
    
    #Remove stopword
    tokens = [word for word in tokens if not word in StopWords]
    
    #Lemmatize
    lemma = WordNetLemmatizer()
    tokens = [lemma.lemmatize(word, pos="v") for word in tokens]
    tokens = [lemma.lemmatize(word, pos="n") for word in tokens]
    
    # list to string
    text = " ".join(tokens)

    return text

# %%
#Text processing
clean_content=[]
for content in speech_df['content'].values.tolist():
    clean_content.append(clean_text(content))
    
speech_df["content_clean"] = clean_content

# %%
#Visually check
speech_df.head()
# Out:
#          date                       title  \
# 0  2010-02-01     2010_Budget_to_Congress
# 1  2016-09-11          911_After_15_Years
# 2  2009-09-11  911_Pentagon_Memorial_2009
# 3  2010-09-11  911_Pentagon_Memorial_2010
# 4  2011-03-18            Address_on_Libya
#
#                                              content  \
# 0   Good morning, everybody. This morning, I sent...
# 1   Good morning.  Scripture tells us, “Let not s...
# 2   Secretary Gates, Admiral Mullen and members o...
# 3   Secretary Gates, Admiral Mullen and members o...
# 4    Good afternoon, everybody.I want to take thi...
#
#                                        content_clean
# 0  good morning everybody morning send budget con...
# 1  good morning scripture tell u let steadfast lo...
# 2  secretary gate admiral mullen member arm force...
# 3  secretary gate admiral mullen member arm force...
# 4  good afternoon want take opportunity update am...

# %%
#Function of extracting nouns from contents of speeches
def nouns_extract(content):
    nouns = []
    content = list(content.split(" "))
    
    for word, pos in nltk.pos_tag(content):
        if (pos == "NN" or pos == "NNP" or pos == "NNS" or pos == "NNPS"):
            nouns.append(word)
            string_nouns = ' '.join(nouns)
    return string_nouns

# %%
#Extract nouns
content_nouns=[]
for content in clean_content:
    content_nouns.append(nouns_extract(content))
    
speech_df["content_nouns"] = content_nouns

# %%
#Visually check
speech_df.head()
# Out:
#          date                       title  \
# 0  2010-02-01     2010_Budget_to_Congress
# 1  2016-09-11          911_After_15_Years
# 2  2009-09-11  911_Pentagon_Memorial_2009
# 3  2010-09-11  911_Pentagon_Memorial_2010
# 4  2011-03-18            Address_on_Libya
#
#                                              content  \
# 0   Good morning, everybody. This morning, I sent...
# 1   Good morning.  Scripture tells us, “Let not s...
# 2   Secretary Gates, Admiral Mullen and members o...
# 3   Secretary Gates, Admiral Mullen and members o...
# 4    Good afternoon, everybody.I want to take thi...
#
#                                        content_clean  \
# 0  good morning everybody morning send budget con...
# 1  good morning scripture tell u let steadfast lo...
# 2  secretary gate admiral mullen member arm force...
# 3  secretary gate admiral mullen member arm force...
# 4  good afternoon want take opportunity update am...
#
#                                        content_nouns
# 0  morning everybody morning budget congress year...
# 1  morning scripture let tablet secretary carter ...
# 2  secretary gate member arm force family day sep...
# 3  secretary gate member arm force survivor trage...
# 4  afternoon take opportunity people situation we...

# %%
#Write the data frame to a txt file named "clean_speeches_df.txt"
speech_df.to_csv(Path.cwd()/"clean_speeches_df.txt", header= True, index= False)
